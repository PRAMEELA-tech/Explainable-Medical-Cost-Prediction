# %%
import os
os.getcwd()
# Out:
# '/teamspace/studios/this_studio/Medical_Cost_Project/notebooks'

# %%
os.listdir("..")
# Out:
# ['models', 'data', 'notebooks', 'kaggle.json']

# %%
os.listdir("../data")
# Out:
# ['insurance.zip', 'insurance.csv']

# %%
df = pd.read_csv("../data/insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import os

print("Current directory:", os.getcwd())
print("Files here:", os.listdir())
# Out:
# Current directory: /teamspace/studios/this_studio/Medical_Cost_Project/notebooks
# Files here: ['M3_Data_Understanding_and_EDA.ipynb']

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df["charges"], bins=40, kde=True)
plt.title("Distribution of Medical Insurance Charges")
plt.xlabel("Charges")
plt.ylabel("Frequency")
plt.show()

# %%
df["charges"].skew()
# Out:
# 1.5158796580240388

# %%
numerical_features = ["age", "bmi", "children"]
numerical_features
# Out:
# ['age', 'bmi', 'children']

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["age"], bins=30, kde=True)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["bmi"], bins=30, kde=True)
plt.title("BMI Distribution")
plt.xlabel("BMI")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["children"], bins=10)
plt.title("Number of Children Distribution")
plt.xlabel("Number of Children")
plt.ylabel("Count")
plt.show()

# %%
categorical_features = ["sex", "smoker", "region"]
categorical_features
# Out:
# ['sex', 'smoker', 'region']

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="sex", data=df)
plt.title("Sex Distribution")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="smoker", data=df)
plt.title("Smoker Distribution")
plt.xlabel("Smoker Status")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="region", data=df)
plt.title("Region Distribution")
plt.xlabel("Region")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x="age", y="charges", data=df, alpha=0.6)
plt.title("Medical Insurance Charges vs Age")
plt.xlabel("Age")
plt.ylabel("Charges")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7,5))
sns.scatterplot(x="bmi", y="charges", data=df, alpha=0.6)
plt.title("Medical Insurance Charges vs BMI")
plt.xlabel("BMI")
plt.ylabel("Charges")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x="smoker", y="charges", data=df)
plt.title("Medical Insurance Charges by Smoker Status")
plt.xlabel("Smoker")
plt.ylabel("Charges")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="region", y="charges", data=df)
plt.title("Medical Insurance Charges by Region")
plt.xlabel("Region")
plt.ylabel("Charges")
plt.show()

# %%
# Compute correlation matrix
corr_matrix = df.corr(numeric_only=True)
corr_matrix
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()
